# %%
def showEmployee(name, salary = 9000):
    #return salary bla bla 
    print('name ', name, 'salary ', salary)

showEmployee("Ben", 12000)
showEmployee("Jessa")
# Out:
# name  Ben salary  12000
# name  Jessa salary  9000
