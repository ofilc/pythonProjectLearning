# %%
from english_words import english_words_lower_alpha_set as ew 
import numpy as np


#collect eligible words
list_words = np.array({x for x in ew if len(x) == 5})
print(type(list_words))
print(list_words)
# Out:
# <class 'numpy.ndarray'>
# ...
